# %%
from RidgeRegression import *

# %%
import pandas as pd

# %%
price_df = pd.read_csv("stock.csv")

# %%
vol_df = pd.read_csv("stock_volume.csv")

# %%
regressor,results,regressor_plot,lr_accuracy = ridge_regressor(price_df,vol_df,"AAPL",ratio = 0.8,n=5)

# %%
results
# Out:
# array([[417.98005127],
#        [431.55617624],
#        [421.24769288],
#        [427.11635205],
#        [414.88952786]])

# %%
regressor_plot

# %%
lr_accuracy
# Out:
# 0.9329813547337712
